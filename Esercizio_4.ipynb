# %% [markdown]
# Liouville: I punti nello spazio delle fasi (traiettorie) non possono scomparire!
# Vedremo la dinamica molecolare con energia (T?), volume e numero di particelle fissati -> microcanonico
# le equazioni del moto contengono errori di discretizzazione -> traiettorie sbagliate, instabilità di lyapunov -> ma ok, basta che siano a energia fissata
# spherical cutoff mantiene isotropia che perdiamo con minimum image convention
# initial conditions: mantenersi lontano dai disastri (es due atomi sovrapposti) -> partiamo sempre da una condizione di cristallina (solido)p

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math

plt.rcParams.update({'font.size': 13})

# %%
datafile = "./data/ave_temp.out"
I, err = np.loadtxt(datafile, usecols=(0, 2), delimiter=' ', unpack='true')

N = 100        # Blocks

x = np.arange(N)
plt.figure(figsize=(10, 5))
plt.grid(True)
plt.errorbar(x, I, yerr=err)

plt.xlabel('# blocks')
plt.ylabel('Temperature')
plt.title('Blocked Temperature Test')
# plt.savefig('./figures/2.1.1.png')
plt.show()
