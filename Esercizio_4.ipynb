# %% [markdown]
# ### 4.1 - Restart
#
# Il codice originale esegue
# Vorremo far ripartire la nostra simulazione usando le ultime due configurazioni della precedente simulazione: <font face="Courier">config.penultimate, config.final </font></span>.
#
# L'ottava riga seleziona la modalità di uso del programma: 0 significa di far eseguire il programma in modalità originale, 1 significa di far ripartire la simulazione da configurazioni precedenti.
#
# Nel secondo caso si può anche optare di far equilibrare rapidamente la temperature della simulazione (le velocità) tramite un processo di riscalamenteo.

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math

plt.rcParams.update({'font.size': 13})

# %%
fig, ax = plt.subplots(2, 2, figsize=(14, 8))
fig.suptitle("Solid Phase")

N = 100  # Blocks
x = np.arange(N)

datafile = "./data/4.3.1/ave_etot.out"
avg, err = np.loadtxt(datafile, usecols=(0, 2), delimiter=' ', unpack='true')
ax[0, 0].errorbar(x, avg, yerr=err, label="etot")
ax[0, 0].title.set_text("Total Energy (LJU)")
ax[0, 0].grid(True)

datafile = "./data/4.3.1/ave_epot.out"
avg, err = np.loadtxt(datafile, usecols=(0, 2), delimiter=' ', unpack='true')
ax[0, 1].errorbar(x, avg, yerr=err,  label="epot")
ax[0, 1].title.set_text("Potential Energy (LJU)")
ax[0, 1].grid(True)

datafile = "./data/4.3.1/ave_ekin.out"
avg, err = np.loadtxt(datafile, usecols=(0, 2), delimiter=' ', unpack='true')
ax[1, 0].errorbar(x, avg, yerr=err, label="ekin")
ax[1, 0].title.set_text("Kinetic Energy (LJU)")
ax[1, 0].grid(True)

datafile = "./data/4.3.1/ave_temp.out"
avg, err = np.loadtxt(datafile, usecols=(0, 2), delimiter=' ', unpack='true')
ax[1, 1].errorbar(x, avg, yerr=err, label="temp (K)")
ax[1, 1].title.set_text("Temperature (LJU)")
ax[1, 1].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 4.2 - Blocked Averages
#
# La seconda modificazione comporta di dover implementare una media a blocchi delle osservabili, come se fossero misure ripetute.

# %%
fig, ax = plt.subplots(2, 2, figsize=(14, 8))
fig.suptitle("Liquid Phase")

N = 100  # Blocks
x = np.arange(N)

datafile = "./data/4.3.2/ave_etot.out"
avg, err = np.loadtxt(datafile, usecols=(0, 2), delimiter=' ', unpack='true')
ax[0, 0].errorbar(x, avg, yerr=err, label="etot")
ax[0, 0].title.set_text("Total Energy (LJU)")
ax[0, 0].grid(True)

datafile = "./data/4.3.2/ave_epot.out"
avg, err = np.loadtxt(datafile, usecols=(0, 2), delimiter=' ', unpack='true')
ax[0, 1].errorbar(x, avg, yerr=err,  label="epot")
ax[0, 1].title.set_text("Potential Energy (LJU)")
ax[0, 1].grid(True)

datafile = "./data/4.3.2/ave_ekin.out"
avg, err = np.loadtxt(datafile, usecols=(0, 2), delimiter=' ', unpack='true')
ax[1, 0].errorbar(x, avg, yerr=err, label="ekin")
ax[1, 0].title.set_text("Kinetic Energy (LJU)")
ax[1, 0].grid(True)

datafile = "./data/4.3.2/ave_temp.out"
avg, err = np.loadtxt(datafile, usecols=(0, 2), delimiter=' ', unpack='true')
ax[1, 1].errorbar(x, avg, yerr=err, label="temp (K)")
ax[1, 1].title.set_text("Temperature (LJU)")
ax[1, 1].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 4.3 - Argon

# %%
fig, ax = plt.subplots(2, 2, figsize=(14, 8))
fig.suptitle("Gas Phase")

N = 100  # Blocks
x = np.arange(N)

datafile = "./data/4.3.3/ave_etot.out"
avg, err = np.loadtxt(datafile, usecols=(0, 2), delimiter=' ', unpack='true')
ax[0, 0].errorbar(x, avg, yerr=err, label="etot")
ax[0, 0].title.set_text("Total Energy (LJU)")
ax[0, 0].grid(True)

datafile = "./data/4.3.3/ave_epot.out"
avg, err = np.loadtxt(datafile, usecols=(0, 2), delimiter=' ', unpack='true')
ax[0, 1].errorbar(x, avg, yerr=err,  label="epot")
ax[0, 1].title.set_text("Potential Energy (LJU)")
ax[0, 1].grid(True)

datafile = "./data/4.3.3/ave_ekin.out"
avg, err = np.loadtxt(datafile, usecols=(0, 2), delimiter=' ', unpack='true')
ax[1, 0].errorbar(x, avg, yerr=err, label="ekin")
ax[1, 0].title.set_text("Kinetic Energy (LJU)")
ax[1, 0].grid(True)

datafile = "./data/4.3.3/ave_temp.out"
avg, err = np.loadtxt(datafile, usecols=(0, 2), delimiter=' ', unpack='true')
ax[1, 1].errorbar(x, avg, yerr=err, label="temp (K)")
ax[1, 1].title.set_text("Temperature (LJU)")
ax[1, 1].grid(True)

plt.tight_layout()
plt.show()
